# %% [markdown]
# **tech_hum посты**

# %%
import pandas as pd

data = pd.read_parquet('post.parquet')
data = data[data['text'] != 'Запись удалена']

def is_russian(text):
  return any(c in 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя' for c in text)

def normalize_text(text):
    if isinstance(text, str):
        if 'http' in text:
           text = " ".join(x for x in text.split() if 'http' not in x)

        text = text.replace('\\n', ' ')
        text = re.sub(r'<br>', ' ', text)
        text = re.sub(r'\s+', ' ', text).strip()
        text = text.lower()
        text = re.sub(r'[^\w\s]', ' ', text)
        text = text.replace(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*(),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '')
 
    return text


data['text'] = data['text'].astype(str)

data = data[data['text'].apply(is_russian)]
data['text'] = data['text'].apply(normalize_text)
#data = data.groupby('user_id')
technical_words = [
  "python", "java", "javascript", "c++", "c#", "php", "swift", "kotlin", "go", "ruby", 
  "rust", "node.js", "react", "angular", "vue.js", "django", "flask", "spring", ".net", 
  "android", "ios", "web разработка", "мобильная разработка", "разработка игр", 
  "машинное обучение", "data science", "искусственный интеллект", "devops", 
  "кибербезопасность", "блокчейн", "git", "github", "agile", "scrum", "kanban", "tdd", 
  "ci/cd", "шаблоны проектирования", "алгоритмы", "структуры данных", "базы данных", 
  "sql", "nosql", "mongodb", "postgresql", "mysql", "oracle", "облачные вычисления", 
  "aws", "azure", "google cloud", "docker", "kubernetes", "linux", "unix", "bash", 
  "скрипты shell", "сети", "tcp/ip", "кибербезопасность", "этический хакер", 
  "тестирование на проникновение", "криптография", "информационная безопасность", 
  "arduino", "raspberry pi", "микроконтроллеры", "встраиваемые системы", "электроника", 
  "проектирование схем", "проектирование печатных плат", "робототехника", "3d печать", 
  "iot", "умный дом", "датчики", "исполнительные механизмы", "силовая электроника", 
  "цифровая обработка сигналов", "аналоговая электроника", "радиотехника", "fpga", 
  "сбис", "полупроводники", "инженерия", "машиностроение", "строительство", 
  "химическая технология", "аэрокосмическая технология", "автомобилестроение", 
  "биотехнологии", "нанотехнологии", "3d моделирование", "сапр", "сам", "solidworks", 
  "autocad", "fusion 360", "математика", "физика", "химия", "биология", "геология", 
  "астрономия", "космонавтика", "энергетика", "экология", "ядерная физика", "медицина", 
  "фармакология", "биохимия", "генетика", "квантовая физика", "нейробиология", 
  "наномедицина", "биоинформатика", "системное администрирование", "сети", "безопасность", 
  "виртуализация", "хранилища данных", "большие данные", "аналитика данных", 
  "информационные системы", "разработка по", "программное обеспечение", "тестирование по", 
  "документирование по", "управление проектами", "методы разработки", "scrum master", 
  "product owner", "аналитик систем", "архитектор систем", "разработчик игр", 
  "game design", "ui/ux design", "графический дизайн", "веб-дизайн", "front-end разработка", 
  "back-end разработка", "full-stack разработка", "интернет маркетинг", "seo", "smm", 
  "контекстная реклама", "email marketing", "digital marketing", "data mining",   "обработка естественного языка", "компьютерное зрение", "распознавание речи", 
  "обработка сигналов", "компьютерная графика", "визуализация данных", "3d анимация", 
  "спецэффекты", "vr/ar", "искусственный интеллект", "машинное обучение", 
  "глубокое обучение", "нейронные сети", "обработка изображений", "обработка видео", 
  "алгоритмы", "криптография", "криптоэкономика", "блокчейн", "ethereum", "bitcoin", 
  "криптовалюты", "nft", "децентрализованные приложения", "web3", "метавселенная", 
  "киберспорт", "кибербезопасность", "этический хакер", "тестирование на проникновение", 
  "информационная безопасность", "сетевая безопасность", "защита данных", "криптография", 
  "пентестинг", "системное администрирование", "сети", "сетевое оборудование", "серверы", 
  "виртуализация", "хранилища данных", "облачные вычисления", "aws", "azure", 
  "google cloud", "docker", "kubernetes", "linux", "unix", "bash", "скрипты shell", 
  "системы управления базами данных", "sql", "nosql", "mongodb", "postgresql", 
  "mysql", "oracle", "big data", "аналитика данных", "data mining", "business intelligence", 
  "data visualization", "информационные системы", "erp", "crm", "bpm", "bi", "scm", 
  "проектирование", "разработка", "инженерное проектирование", "промышленный дизайн", 
  "графический дизайн", "веб-дизайн", "ui/ux design", "анимация", "3d моделирование", 
  "cad", "cam", "solidworks", "autocad", "fusion 360", "проектирование зданий", 
  "архитектура", "строительство", "инженерные коммуникации", "энергетика", 
  "энергоэффективность", "возобновляемые источники энергии", "водоснабжение", "канализация", 
  "теплоснабжение", "вентиляция", "кондиционирование", "отопление", "автоматизация", 
  "робототехника", "мехатроника", "искусственный интеллект", "машинное обучение", 
  "глубокое обучение", "нейронные сети", "computer vision", "распознавание речи", 
  "обработка естественного языка", "алгоритмы", "математическое моделирование", 
  "системы управления", "автоматизированные системы управления", "программируемые логические контроллеры", 
  "plc", "scada", "iot", "умный дом", "интернет вещей", "биоинженерия", "биомедицинская инженерия", 
  "генетическая инженерия", "биотехнологии", "нанотехнологии", "материалы", "новые материалы", 
  "композитные материалы", "металлургия", "химическая технология", "фармацевтика", 
  "космонавтика", "аэрокосмическая промышленность", "авиастроение", "ракетостроение", 
  "спутниковая связь", "транспорт", "автомобильная промышленность", "железнодорожный транспорт", 
  "судостроение", "авиация", "судовые двигатели", "электрический транспорт", 
  "беспилотные летательные аппараты", "робототехника", "искусственный интеллект", 
  "машинное обучение", "глубокое обучение", "нейронные сети", "computer vision", 
  "распознавание речи", "обработка естественного языка", "алгоритмы", 
  "математическое моделирование", "системы управления"
]

humanities_words = [
 "литература", "литература", "literature",
 "история", "история", "history",
 "философия", "философия", "philosophy",
 "психология", "психология", "psychology",
 "социология", "социология", "sociology",
 "антропология", "антропология", "anthropology",
 "культурология", "культура", "culture",
 "языкознание", "язык", "language",
 "лингвистика", "язык", "language",
 "филология", "язык", "language",
 "искусствоведение", "искусство", "art",
 "музыковедение", "музыка", "music",
 "театроведение", "театр", "theatre",
 "киноведение", "кино", "cinema",
 "архитектура", "архитектура", "architecture",
 "дизайн", "дизайн", "design",
 "искусство", "искусство", "art",
 "музыка", "музыка", "music",
 "театр", "театр", "theatre",
 "кино", "кино", "cinema",
 "живопись", "живопись", "painting",
 "скульптура", "скульптура", "sculpture",
 "графика", "графика", "graphics",
 "фотоискусство", "фотография", "photography",
 "литература", "литература", "literature",
 "поэзия", "поэзия", "poetry",
 "проза", "проза", "prose",
 "драматургия", "драма", "drama",
 "журналистика", "журнал", "journalism",
 "реклама", "реклама", "advertising",
 "public relations", "relations", "public relations",
 "маркетинг", "маркетинг", "marketing",
 "менеджмент", "управление", "management",
 "экономика", "экономика", "economics",
 "политология", "политика", "politics",
 "право", "право", "law",
 "социология", "социология", "sociology",
 "история", "история", "history",
 "философия", "философия", "philosophy",
 "религия", "религия", "religion",
 "этика", "этика", "ethics",
 "мораль", "мораль", "morality",
 "культура", "культура", "culture",
 "традиции", "традиция", "tradition",
 "обычаи", "обычай", "custom",
 "ритуалы", "ритуал", "ritual",
 "мифология", "миф", "mythology",
 "фольклор", "народ", "folklore",
 "этнография", "народ", "ethnography",
 "антропология", "anthropology",
 "психология", "душа", "psychology",
 "когнитивная наука", "знание", "cognitive science",
 "нейропсихология", "нерв", "neuropsychology",
 "педагогика", "дети", "pedagogy",
 "психотерапия", "терапия", "psychotherapy",
 "социология", "социология", "sociology",
 "социокультурная антропология", "человек", "sociocultural anthropology",
 "политология", "политика", "politics",
 "международные отношения", "отношения", "international relations",
 "политическая философия", "политика", "political philosophy",
 "право", "право", "law",
 "юриспруденция", "право", "jurisprudence",
 "криминология", "преступление", "criminology",
 "история права", "право", "history of law",
 "филология", "язык", "philology",
 "лингвистика", "язык", "linguistics",
 "языкознание", "язык", "linguistics",
 "перевод", "перевод", "translation",
 "литература", "литература", "literature",
 "поэзия", "поэзия", "poetry",
 "проза", "проза", "prose",
 "драматургия", "драма", "drama",
 "литературная критика", "критика", "literary criticism",
 "искусствоведение", "искусство", "art history",
 "музыковедение", "музыка", "musicology",
 "театроведение", "театр", "theatre studies",
 "киноведение", "кино", "film studies",
 "архитектура", "архитектура", "architecture",
 "дизайн", "дизайн", "design",
 "искусство", "искусство", "art",
 "музыка", "музыка", "music",
 "театр", "театр", "theatre",
 "кино", "кино", "cinema",
 "живопись", "живопись", "painting",
 "скульптура", "скульптура", "sculpture",
 "графика", "графика", "graphics",
 "фотоискусство", "фотография", "photography",
 "музейное дело", "музей", "museum studies",
 "архивоведение", "архив", "archives",
 "историография", "история", "historiography",
 "этнография", "народ", "ethnography",
 "антропология", "человек", "anthropology",
 "археология", "древность", "archeology",
 "палеоантропология", "древность", "paleoanthropology",
]

res = pd.DataFrame(columns=['user_id', 'tech', 'hum'])

for user_id, gr in data.groupby('user_id'):
    counter_tech, counter_hum = 0, 0
    
    gr['text'].fillna('', inplace=True) 
    for w in technical_words:
        counter_tech += gr[gr['text'].str.lower().str.contains(w)].shape[0]
    for w in humanities_words:
        counter_hum += gr[gr['text'].str.lower().str.contains(w)].shape[0]
    new_row = pd.DataFrame({'user_id': [user_id], 'tech': [counter_tech], 'hum':[counter_hum]})
    res = pd.concat([res, new_row])

res.to_csv("tech_hum_posts.csv")
res.head()
# Out:
# C:\Users\sunik\AppData\Local\Temp\ipykernel_19864\4237476884.py:196: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gr['text'].fillna('', inplace=True)
#   user_id tech hum
# 0     357    7  11
# 0     359    0   0
# 0     360    0   0
# 0     363    0   0
# 0     364    5   6

# %% [markdown]
# **tech_hum_groups**

# %%
import re
import pandas as pd

def normalize_text(text):
    if isinstance(text, str):
        if 'http' in text:
           text = " ".join(x for x in text.split() if 'http' not in x)

        text = text.replace('\\n', ' ')
        text = re.sub(r'<br>', ' ', text)
        text = re.sub(r'\s+', ' ', text).strip()
        text = text.lower()
        text = re.sub(r'[^\w\s]', ' ', text)
        text = text.replace(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*(),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '')
 
        return text
    return ''

data = pd.read_parquet('group_table.parquet')
data.head()
data['name'] = data['name'].astype(str) 
data['description'] = data['description'].astype(str)
data['name'].fillna('', inplace=True)
data['description'].fillna('', inplace=True)

data['result'] = (data['name'] + ' ' + data['description']).str.replace('\\n', ' ')
data['result'] = data['result'].apply(normalize_text)
data = data.drop(['name', 'description'], axis=1)
technical_words = [
  "python", "java", "javascript", "c++", "c#", "php", "swift", "kotlin", "go", "ruby", 
  "rust", "node.js", "react", "angular", "vue.js", "django", "flask", "spring", ".net", 
  "android", "ios", "web разработка", "мобильная разработка", "разработка игр", 
  "машинное обучение", "data science", "искусственный интеллект", "devops", 
  "кибербезопасность", "блокчейн", "git", "github", "agile", "scrum", "kanban", "tdd", 
  "ci/cd", "шаблоны проектирования", "алгоритмы", "структуры данных", "базы данных", 
  "sql", "nosql", "mongodb", "postgresql", "mysql", "oracle", "облачные вычисления", 
  "aws", "azure", "google cloud", "docker", "kubernetes", "linux", "unix", "bash", 
  "скрипты shell", "сети", "tcp/ip", "кибербезопасность", "этический хакер", 
  "тестирование на проникновение", "криптография", "информационная безопасность", 
  "arduino", "raspberry pi", "микроконтроллеры", "встраиваемые системы", "электроника", 
  "проектирование схем", "проектирование печатных плат", "робототехника", "3d печать", 
  "iot", "умный дом", "датчики", "исполнительные механизмы", "силовая электроника", 
  "цифровая обработка сигналов", "аналоговая электроника", "радиотехника", "fpga", 
  "сбис", "полупроводники", "инженерия", "машиностроение", "строительство", 
  "химическая технология", "аэрокосмическая технология", "автомобилестроение", 
  "биотехнологии", "нанотехнологии", "3d моделирование", "сапр", "сам", "solidworks", 
  "autocad", "fusion 360", "математика", "физика", "химия", "биология", "геология", 
  "астрономия", "космонавтика", "энергетика", "экология", "ядерная физика", "медицина", 
  "фармакология", "биохимия", "генетика", "квантовая физика", "нейробиология", 
  "наномедицина", "биоинформатика", "системное администрирование", "сети", "безопасность", 
  "виртуализация", "хранилища данных", "большие данные", "аналитика данных", 
  "информационные системы", "разработка по", "программное обеспечение", "тестирование по", 
  "документирование по", "управление проектами", "методы разработки", "scrum master", 
  "product owner", "аналитик систем", "архитектор систем", "разработчик игр", 
  "game design", "ui/ux design", "графический дизайн", "веб-дизайн", "front-end разработка", 
  "back-end разработка", "full-stack разработка", "интернет маркетинг", "seo", "smm", 
  "контекстная реклама", "email marketing", "digital marketing", "data mining",   "обработка естественного языка", "компьютерное зрение", "распознавание речи", 
  "обработка сигналов", "компьютерная графика", "визуализация данных", "3d анимация", 
  "спецэффекты", "vr/ar", "искусственный интеллект", "машинное обучение", 
  "глубокое обучение", "нейронные сети", "обработка изображений", "обработка видео", 
  "алгоритмы", "криптография", "криптоэкономика", "блокчейн", "ethereum", "bitcoin", 
  "криптовалюты", "nft", "децентрализованные приложения", "web3", "метавселенная", 
  "киберспорт", "кибербезопасность", "этический хакер", "тестирование на проникновение", 
  "информационная безопасность", "сетевая безопасность", "защита данных", "криптография", 
  "пентестинг", "системное администрирование", "сети", "сетевое оборудование", "серверы", 
  "виртуализация", "хранилища данных", "облачные вычисления", "aws", "azure", 
  "google cloud", "docker", "kubernetes", "linux", "unix", "bash", "скрипты shell", 
  "системы управления базами данных", "sql", "nosql", "mongodb", "postgresql", 
  "mysql", "oracle", "big data", "аналитика данных", "data mining", "business intelligence", 
  "data visualization", "информационные системы", "erp", "crm", "bpm", "bi", "scm", 
  "проектирование", "разработка", "инженерное проектирование", "промышленный дизайн", 
  "графический дизайн", "веб-дизайн", "ui/ux design", "анимация", "3d моделирование", 
  "cad", "cam", "solidworks", "autocad", "fusion 360", "проектирование зданий", 
  "архитектура", "строительство", "инженерные коммуникации", "энергетика", 
  "энергоэффективность", "возобновляемые источники энергии", "водоснабжение", "канализация", 
  "теплоснабжение", "вентиляция", "кондиционирование", "отопление", "автоматизация", 
  "робототехника", "мехатроника", "искусственный интеллект", "машинное обучение", 
  "глубокое обучение", "нейронные сети", "computer vision", "распознавание речи", 
  "обработка естественного языка", "алгоритмы", "математическое моделирование", 
  "системы управления", "автоматизированные системы управления", "программируемые логические контроллеры", 
  "plc", "scada", "iot", "умный дом", "интернет вещей", "биоинженерия", "биомедицинская инженерия", 
  "генетическая инженерия", "биотехнологии", "нанотехнологии", "материалы", "новые материалы", 
  "композитные материалы", "металлургия", "химическая технология", "фармацевтика", 
  "космонавтика", "аэрокосмическая промышленность", "авиастроение", "ракетостроение", 
  "спутниковая связь", "транспорт", "автомобильная промышленность", "железнодорожный транспорт", 
  "судостроение", "авиация", "судовые двигатели", "электрический транспорт", 
  "беспилотные летательные аппараты", "робототехника", "искусственный интеллект", 
  "машинное обучение", "глубокое обучение", "нейронные сети", "computer vision", 
  "распознавание речи", "обработка естественного языка", "алгоритмы", 
  "математическое моделирование", "системы управления", "решаю"
]

humanities_words = [
 "литература", "литература", "literature",
 "история", "история", "history",
 "философия", "философия", "philosophy",
 "психология", "психология", "psychology",
 "социология", "социология", "sociology",
 "антропология", "антропология", "anthropology",
 "культурология", "культура", "culture",
 "языкознание", "язык", "language",
 "лингвистика", "язык", "language",
 "филология", "язык", "language",
 "искусствоведение", "искусство", "art",
 "музыковедение", "музыка", "music",
 "театроведение", "театр", "theatre",
 "киноведение", "кино", "cinema",
 "архитектура", "архитектура", "architecture",
 "дизайн", "дизайн", "design",
 "искусство", "искусство", "art",
 "музыка", "музыка", "music",
 "театр", "театр", "theatre",
 "кино", "кино", "cinema",
 "живопись", "живопись", "painting",
 "скульптура", "скульптура", "sculpture",
 "графика", "графика", "graphics",
 "фотоискусство", "фотография", "photography",
 "литература", "литература", "literature",
 "поэзия", "поэзия", "poetry",
 "проза", "проза", "prose",
 "драматургия", "драма", "drama",
 "журналистика", "журнал", "journalism",
 "реклама", "реклама", "advertising",
 "public relations", "relations", "public relations",
 "маркетинг", "маркетинг", "marketing",
 "менеджмент", "управление", "management",
 "экономика", "экономика", "economics",
 "политология", "политика", "politics",
 "право", "право", "law",
 "социология", "социология", "sociology",
 "история", "история", "history",
 "философия", "философия", "philosophy",
 "религия", "религия", "religion",
 "этика", "этика", "ethics",
 "мораль", "мораль", "morality",
 "культура", "культура", "culture",
 "традиции", "традиция", "tradition",
 "обычаи", "обычай", "custom",
 "ритуалы", "ритуал", "ritual",
 "мифология", "миф", "mythology",
 "фольклор", "народ", "folklore",
 "этнография", "народ", "ethnography",
 "антропология", "anthropology",
 "психология", "душа", "psychology",
 "когнитивная наука", "знание", "cognitive science",
 "нейропсихология", "нерв", "neuropsychology",
 "педагогика", "дети", "pedagogy",
 "психотерапия", "терапия", "psychotherapy",
 "социология", "социология", "sociology",
 "социокультурная антропология", "человек", "sociocultural anthropology",
 "политология", "политика", "politics",
 "международные отношения", "отношения", "international relations",
 "политическая философия", "политика", "political philosophy",
 "право", "право", "law",
 "юриспруденция", "право", "jurisprudence",
 "криминология", "преступление", "criminology",
 "история права", "право", "history of law",
 "филология", "язык", "philology",
 "лингвистика", "язык", "linguistics",
 "языкознание", "язык", "linguistics",
 "перевод", "перевод", "translation",
 "литература", "литература", "literature",
 "поэзия", "поэзия", "poetry",
 "проза", "проза", "prose",
 "драматургия", "драма", "drama",
 "литературная критика", "критика", "literary criticism",
 "искусствоведение", "искусство", "art history",
 "музыковедение", "музыка", "musicology",
 "театроведение", "театр", "theatre studies",
 "киноведение", "кино", "film studies",
 "архитектура", "архитектура", "architecture",
 "дизайн", "дизайн", "design",
 "искусство", "искусство", "art",
 "музыка", "музыка", "music",
 "театр", "театр", "theatre",
 "кино", "кино", "cinema",
 "живопись", "живопись", "painting",
 "скульптура", "скульптура", "sculpture",
 "графика", "графика", "graphics",
 "фотоискусство", "фотография", "photography",
 "музейное дело", "музей", "museum studies",
 "архивоведение", "архив", "archives",
 "историография", "история", "historiography",
 "этнография", "народ", "ethnography",
 "антропология", "человек", "anthropology",
 "археология", "древность", "archeology",
 "палеоантропология", "древность", "paleoanthropology", "рисую", "пою", "танцую"
]

res = pd.DataFrame(columns=['user_id', 'tech', 'hum'])

for user_id, gr in data.groupby('user_id'):
    counter_tech, counter_hum = 0, 0
    
    gr['result'].fillna('', inplace=True) 
    for w in technical_words:
        counter_tech += gr[gr['result'].str.lower().str.contains(w)].shape[0]
    for w in humanities_words:
        counter_hum += gr[gr['result'].str.lower().str.contains(w)].shape[0]
    new_row = pd.DataFrame({'user_id': [user_id], 'tech': [counter_tech], 'hum':[counter_hum]})
    res = pd.concat([res, new_row])

res.to_csv("tech_hum_groups.csv")
res.head()
# Out:
# C:\Users\sunik\AppData\Local\Temp\ipykernel_19864\2594342848.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['name'].fillna('', inplace=True)
# C:\Users\sunik\AppData\Local\Temp\ipykernel_19864\2594342848.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# **Мержим**

# %%
df1 = pd.read_csv('tech_hum_groups.csv')
#df1 = df1.drop('Unnamed: 0', axis=1)
df2 = pd.read_csv('tech_hum_posts.csv')
merged = pd.concat([df1, df2])
result = merged.groupby('user_id').sum()
result.to_csv('sumOfTechHumTagsInGroupsAndPosts.csv')
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 357 to 506
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  150 non-null    int64
#  1   tech        150 non-null    int64
#  2   hum         150 non-null    int64
# dtypes: int64(3)
# memory usage: 4.7 KB
